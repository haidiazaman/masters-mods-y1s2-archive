# %% [markdown]
# # Sequence classification
#
# In this notebook, we apply RNN and its variants to predict the positivity of movie reviews. This notebook serves the following purposes:
#   * Introduce basic usage of RNN and its variants
#   * Introduce basic text data handling

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pathlib
sns.set_theme(font_scale=1.5, style='darkgrid')

# %% [markdown]
# # The IMDB Dataset

# %% [markdown]
# We will use the [IMDB dataset](http://ai.stanford.edu/~amaas/data/sentiment/) consisting of movie reviews of various movie titles.
#
# Our goal is to develop a machine learning model which can predict, given a text review, whether the sentiment of the review is postive (1) or negative (0).
#
# THe IMDB dataset is built into `keras.datasets`.

# %%
from tensorflow.keras.datasets import imdb

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=20000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %% [markdown]
# We can see that the inputs are already coded into integers

# %%
print(x_train[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %% [markdown]
# These are actually word encodings based on frequency. For details, have a look a the documentation of the dataset, e.g. [here](https://keras.io/api/datasets/imdb/).
#
# To see what the review text actually is, we write a simple function that converts the encodings back into words. This is done using the `imdb.get_word_index()` method.

# %%
def to_words(word_ids):
    """
    Convert list of word_ids back to words.
    Special chars for 0-3 are based on the default kwargs of
    imdb.load_data()
    """
    index_from = 3
    word_to_id = imdb.get_word_index()
    word_to_id = {k: (v + index_from) for k, v in word_to_id.items()}
    word_to_id['<PAD>'] = 0
    word_to_id['<START>'] = 1
    word_to_id['<UNK>'] = 2
    word_to_id['<UNUSED>'] = 3
    id_to_word = {value: key for key, value in word_to_id.items()}
    return ' '.join(id_to_word[id] for id in word_ids)

# %% [markdown]
# Let us look at some randomly chosen reviews:

# %%
idx = np.random.choice(len(x_train))
print('Sentiment: ', y_train[idx])
print('Review: ', to_words(x_train[idx]))
# Out:
# Sentiment:  0
# Review:  <START> the flock is not really a movie it's a wannabe movie with wannabe actors not including richard gere he gave an excellent performance but when only one of the actors truly gives himself to his character and the rest of the cast is just acting the result is pathetic just like this movie you see the idea of acting is to hide the fact that you're acting what the hell was claire <UNK> doing in this one she's the most inappropriate actress for this character in 99 9 of the movie she looked extremely out of place out of everything the only thing she was doing was asking stupid questions like do you really think so and making silly faces i was embarrassed by her acting seriously and i used to like her she's the romantic movie type i don't know who picked her among all the actresses out there lol and seeing <UNK> <UNK> this really made me laugh anyway if you want to get the feeling of throwing up this movie will do the job for you i wish i could vote 5

# %% [markdown]
# The goal is to predict the sentiment
# - 1: positive
# - 0: negative
#
# Based on the text.
#
# Now, this is a text classification problem, but it is indeed a special case of sequence to sequence model where the output sequence is a binary sequence of length 1.

# %% [markdown]
# ## Preprocessing the data for training

# %% [markdown]
# Let us check what is the length (number of words) for each review.

# %%
lengths_train = list(map(len, x_train))

# %%
ax = sns.histplot(lengths_train, kde=True)
ax.set_xlabel('Number of Words')
# Out:
# Text(0.5, 0, 'Number of Words')

# %% [markdown]
# The number of words clearly varies from review to review, so we pad them. This is performed by the `sequence.pad_sequences` function. Any review longer than `maxlen` is cut off, and those shorter are padded (in the front) by 0s.

# %%
from tensorflow.keras.preprocessing import sequence

# %%
x_train = sequence.pad_sequences(x_train, maxlen=100)
x_test = sequence.pad_sequences(x_test, maxlen=100)

# %%
print(x_train.shape, y_train.shape)
# Out:
# (25000, 100) (25000,)

# %% [markdown]
# # Build a Simple RNN Model

# %% [markdown]
# Now, we are ready to build a RNN model to learn to predict the sentiment given the review text.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, SimpleRNN, Input
from tensorflow.keras.optimizers import Adam
from tqdm.keras import TqdmCallback

# %%
model = Sequential()
model.add(Input(shape=(100,)))  # 250x250 RGB images

# %% [markdown]
# Here, we cannot directly work with x_train because they are encoded integers. Instead, we first use an `Embedding` layer that casts these integer encodings to a feature space.
#
# For example, `Embedding(5, 2)` is a 5x2 matrix that maps integer encodings (0,...,4) into 5 real-valued vectors of 2 dimensions:
#
# | Coding | Embedded Vectors
# | --- | --- |
# | 0 | [0.5, 1.0] |
# | 1 | [1.0, 1.2] |
# | 2 | [0.1, -0.6] |
# | 3 | [0.3, 0.5] |
# | 4 | [-0.4, -0.1] |
#
# This embedding is trainable, so we can learn to embed these encodings in the right way relevant to the task: words of similar meaning should have similar embeddings!

# %%
model.add(Embedding(20000, 128))

# %% [markdown]
# Now, we can add the RNN layers, and append to it an output `Dense` layer.

# %%
model.add(SimpleRNN(128))  # 128 is the number of hidden states (dim of h)
model.add(Dense(1, activation='sigmoid'))  # sigmoid activation for binary classification

# %% [markdown]
# We can view a summary of the model.

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 100, 128)       │     2,560,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_3 (SimpleRNN)        │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,593,025 (9.89 MB)
#  Trainable params: 2,593,025 (9.89 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Since we are going to test several models, we will write some functions to train, save and evaluate models. These functions are self-explanatory.

# %%
def train_and_save(model, path, force=False, optimizer=Adam(0.001)):
    """
    Looks for saved model in path, if found, load.
    If not, compile, train and save model to path
    If force=True, will always retrain
    """
    model_save_dir = pathlib.Path(path).with_suffix('.weights.h5')

    model.compile(
        loss='binary_crossentropy',
        optimizer=optimizer,
        metrics=['accuracy'],
    )

    if model_save_dir.exists() and not force:
        model.load_weights(str(model_save_dir))
    else:
        history = model.fit(
            x_train,
            y_train,
            batch_size=32,
            epochs=15,
            validation_data=(x_test, y_test),
            callbacks=[TqdmCallback(verbose=1)],
            verbose=0,
        )
        model.save_weights(str( model_save_dir))
        results = pd.DataFrame(history.history)
        results['epoch'] = history.epoch
        return results

# %%
def evaluate(model, train_data, test_data):
    """
    Evaluate model on train/test sets
    """
    eval_train = model.evaluate(*train_data, batch_size=512, verbose=0)
    eval_test = model.evaluate(*test_data, batch_size=512, verbose=0)
    print(f'Train - loss = {eval_train[0]:.3f}, acc = {eval_train[1]:.3f} ')
    print(f'Test - loss = {eval_test[0]:.3f}, acc = {eval_test[1]:.3f} ')

# %%
train_and_save(model=model, path='imdb_simple_rnn')

# %%
evaluate(model, train_data=(x_train, y_train), test_data=(x_test, y_test))
# Out:
# Train - loss = 0.393, acc = 0.823
# Test - loss = 0.670, acc = 0.668

# %% [markdown]
# # Deep RNN

# %% [markdown]
# Now, we train a deep RNN model by stacking two RNN cells together. This is done simply by adding another `model.add` call. However, note that other than the last RNN cell, "hidden" RNN cells need to have `return_sequences` set to `True`, so that the entire hidden sequence $h^{(t)}$, is returned, and hence can be treated as inputs for the next layer.

# %%
model = Sequential()
model.add(Embedding(20000, 128))
model.add(SimpleRNN(128, return_sequences=True))
model.add(SimpleRNN(64, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# RNNs are notoriously hard to train. For this deeper model, we will use a smaller learning rate than before for the Adam optimizer.

# %%
train_and_save(model=model, path='imdb_deep_rnn', optimizer=Adam(0.0001))
# Out:
# /Users/qianxiao/.venvs/dsa5206_202324/lib/python3.11/site-packages/keras/src/saving/saving_lib.py:396: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 20 variables.
#   trackable.load_own_variables(weights_store.get(inner_path))

# %%
evaluate(model, train_data=(x_train, y_train), test_data=(x_test, y_test))
# Out:
# Train - loss = 0.004, acc = 0.999
# Test - loss = 0.999, acc = 0.788

# %% [markdown]
# Observe that by going deeper we actually manage to do a little better than before!

# %% [markdown]
# # LSTM

# %% [markdown]
# Now, we can also try to improve performance using LSTM, which makes learning long-time dependence much easier. The implementation is very simple -- we just substitute all calls to `SimpleRNN` by `LSTM`.

# %%
from tensorflow.keras.layers import LSTM

# %%
model = Sequential()
model.add(Embedding(20000, 128))
model.add(LSTM(128))
model.add(Dense(1, activation='sigmoid'))

# %%
train_and_save(model=model, path='imdb_lstm')
# Out:
# 0epoch [00:00, ?epoch/s]
# 0batch [00:00, ?batch/s]
#     accuracy      loss  val_accuracy  val_loss  epoch
# 0    0.81304  0.409703       0.82456  0.406182      0
# 1    0.90836  0.237592       0.84196  0.398960      1
# 2    0.94804  0.143211       0.83288  0.450857      2
# 3    0.96704  0.095656       0.83036  0.485135      3
# 4    0.97800  0.064663       0.83732  0.630312      4
# 5    0.98860  0.036658       0.82708  0.721823      5
# 6    0.99200  0.026586       0.83204  0.784674      6
# 7    0.99200  0.025767       0.82544  0.701342      7
# 8    0.99220  0.023005       0.83064  0.825802      8
# 9    0.99684  0.010409       0.82700  0.850127      9
# 10   0.99660  0.010917       0.82440  0.892417     10
# 11   0.99492  0.016526       0.82720  0.980608     11
# 12   0.99700  0.010103       0.82956  0.999638     12
# 13   0.99796  0.006641       0.82700  1.080706     13
# 14   0.99792  0.006040       0.82420  0.987218     14

# %%
evaluate(model, train_data=(x_train, y_train), test_data=(x_test, y_test))
# Out:
# Train - loss = 0.005, acc = 0.999
# Test - loss = 0.851, acc = 0.829

# %% [markdown]
# # Exercise

# %% [markdown]
# 1. Play around with the above models and optimizer configurations to get better models.
# 2. Observe that the training accuracy is much greater than the test accuracy. What can you do to improve generalization?
#
# ## Further reading
# More generally, please check out the follow tutorial (credit: Shida Wang and Fusheng Liu) on pytorch implementations of seq2seq language translation using various recurrent architectures.
#
# https://github.com/radarFudan/SSM_examples
